# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1, 2, 3, 4, 5])
y=np.array([5.3, 6.3,7.3,8.5,9.6])
n=len(x)

data = pd.DataFrame([x, y])
data = data.T
data.columns = (['x', 'y'])
print(data)
# Out:
#      x    y
# 0  1.0  5.3
# 1  2.0  6.3
# 2  3.0  7.3
# 3  4.0  8.5
# 4  5.0  9.6

# %%
x_mean,y_mean = np.mean(x),np.mean(y)
a = np.sum((x-x_mean)*(y-y_mean))/np.sum((x-x_mean)**2)
b = y_mean - a*x_mean

# %%
fig,ax  = plt.subplots()
ax.scatter(x,y)
ax.axline((0,b),slope=a,color='C0',label='linear regression model line')

ax.legend()

plt.show()
